# %% [markdown]
# ## Run run_eda.py in notebook
#
# ### First import the module

# %%
import research.run_eda as run_eda

# %% [markdown]
# ### Then run it

# %%
data = run_eda.main()
print(f"Data shape:\n{data.shape}")
print(f"Data columns:\n{data.columns.values}")
# Out:
# Data shape:
# (891, 12)
# Data columns:
# ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']
